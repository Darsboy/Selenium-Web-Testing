# %%
from selenium import webdriver
import time

# %%
d = webdriver.Firefox()
d.get("https://www.thestar.com/")

# %%
d.find_element_by_link_text('HOME').click()

# %% [markdown]
# # need to: xattr -d com.apple.quarantine chromedriver

# %%
d.find_element_by_link_text('Watch: Blue Jays GM Ross Atkins addresses allegations against Mickey Callaway from time in Cleveland')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-14-fd24505efa52> in <module>
# ----> 1 d.find_element_by_link_text('Watch: Blue Jays GM Ross Atkins addresses allegations against Mickey Callaway from time in Cleveland')
#
# ~/opt/anaconda3/envs/SQlDataBaseFun/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_link_text(self, link_text)
#     426             element = driver.find_element_by_link_text('Sign In')
#     427         """
# --> 428         return self.find_element(by=By.LINK_TEXT, value=link_text)
#     429
#     430     def find_elements_by_link_text(self, text):
#
# ~/opt/anaconda3/envs/SQlDataBaseFun/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# ...

# %%
d.find_element_by_xpath('/html/body/div[1]/div/main/div[2]/div/div[1]/div[1]/div/div[2]/div/div[1]/div/div/a/div[2]/div[2]/h3/span').click()

# %%
d.back()

# %%
d.find_element_by_class_name('c-feature-mediacard__headlines').click()
